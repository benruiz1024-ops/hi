# %% [markdown]
# # ⚡ Lily Video Studio V3
# **Use T4 x2 if Kaggle lets you choose it.** V3 also detects P100 and installs a compatible PyTorch build before touching CUDA.
#
# Run the single cell below and **do not stop it while pip/model downloads are visibly progressing**.

# %%
import urllib.request, pathlib
url='https://raw.githubusercontent.com/benruiz1024-ops/hi/main/lily_ltx_v3.py'
dst=pathlib.Path('/kaggle/working/lily_ltx_v3.py')
urllib.request.urlretrieve(url,dst)
exec(compile(dst.read_text(),str(dst),'exec'))
