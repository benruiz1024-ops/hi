# %% [markdown]
# # 🎥 LILY ACTUALLY-WORKS LTX 2B — Kaggle image → video
#
# In Kaggle: **Settings → Accelerator → GPU T4 x2** if available (one T4 also works), turn **Internet ON**, then **Run All**.
#
# It launches a separate Gradio page. The first startup downloads the model; later generations reuse it.

# %%
import urllib.request, pathlib
url = 'https://raw.githubusercontent.com/benruiz1024-ops/hi/main/LILY_ACTUALLY_WORKS_LTX2B_KAGGLE.py'
dst = pathlib.Path('/kaggle/working/LILY_ACTUALLY_WORKS_LTX2B_KAGGLE.py')
urllib.request.urlretrieve(url, dst)
code = dst.read_text(encoding='utf-8')
exec(compile(code, str(dst), 'exec'))
