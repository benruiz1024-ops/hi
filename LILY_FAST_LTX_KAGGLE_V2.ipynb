# %% [markdown]
# # ⚡ Lily Fast LTX — V2 Disk Fix
# This version stores giant Hugging Face downloads in `/kaggle/tmp` instead of the 20 GB `/kaggle/working` partition.
#
# Turn on **GPU** and **Internet**, then run the cell below. It installs, downloads, loads the model once, and launches the phone-friendly UI.

# %%
# !wget -q -O /kaggle/working/lily_fast_ltx_v2.py https://raw.githubusercontent.com/benruiz1024-ops/hi/main/lily_fast_ltx_v2.py
# %run /kaggle/working/lily_fast_ltx_v2.py
